# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/EstudoEmCasaPCD/blob/main/Revis%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile README.md
# # Esse hashtag é do título
# Teste editando o readme.
#
# ## Esse é um título menor
# Texto normal hehe
# Out:
# Overwriting README.md

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 118419 files and directories currently installed.)
# Preparing to unpack .../archives/gh_2.100.0_amd64.deb ...
# Unpacking gh (2.100.0) over (2.98.0) ...
# Setting up gh (2.100.0) ...
# Processing triggers for man-db (2.10.2-1) ...
#
# ! First copy your one-time code: 71C1-E8D2
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as miguelramos-netizen
# github.com
#   ✓ Logged in to github.com account miguelramos-netizen (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
# ...

# %%
# %cd EstudoEmCasaPCD
# !ls
# !git status
# !git remote -v
# !ls
# Out:
# /content/EstudoEmCasaPCD
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/miguelramos-netizen/EstudoEmCasaPCD.git (fetch)
# origin	https://github.com/miguelramos-netizen/EstudoEmCasaPCD.git (push)
# README.md

# %%
# !git add README.md
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Teste para mandar p github com comandos"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git pull origin main
# !git push origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 1.75 KiB | 896.00 KiB/s, done.
# From https://github.com/miguelramos-netizen/EstudoEmCasaPCD
#  * branch            main       -> FETCH_HEAD
#    da8a187..707a7f5  main       -> origin/main
# Updating da8a187..707a7f5
# Fast-forward
#  "Revis\303\243o_Python.ipynb" | 58 +++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 58 insertions(+)
#  create mode 100644 "Revis\303\243o_Python.ipynb"
# Everything up-to-date
