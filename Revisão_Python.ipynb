# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/EstudoEmCasaPCD/blob/main/Revis%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
x = random.randint(1,10)
print (x)

if x == 0:
  print ("X é 0")
elif x%2 == 0:
  print ("X é par")
elif x%2 ==1:
  print ("X é ímpar")
else:
  print("x não é inteiro natural")
# Out:
# 2
# X é par

# %% [markdown]
# Crie um programa onde o computador "pensa" em um número secreto, e o usuário precisa adivinhar qual é. O programa deve continuar pedindo palpites até que o usuário acerte.

# %%
import random
xresposta = 11
x = random.randint(1, 10)

while xresposta != x:
  xresposta = int (input("tente acertar o valor de X  "))


print ("parabéns acertou")
# Out:
# tente acertar o valor de X  1
# parabéns acertou

# %%
senha = "1234"
chute = 0

while senha != chute:
  chute = (input("tente acertar a senha de 4 dígitos"))


print ("parabéns acertou")
# Out:
# tente acertar a senha de 4 dígitos1553
# tente acertar a senha de 4 dígitos1234
# parabéns acertou
