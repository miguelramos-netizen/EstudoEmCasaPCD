# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/EstudoEmCasaPCD/blob/main/Revis%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crie um programa que pergunte ao usuário um número e, em seguida, calcule e mostre na tela a tabuada de multiplicação desse número, do 1 ao 10.

# %%
numero = int(input("diga um número para fazer a tabuada do 1 a 10  "))

for x in range(0, 11, 1):
  print (numero * x)
# Out:
# diga um número para fazer a tabuada do 1 a 10  9
# 0
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %% [markdown]
# Ex: passar lendo listas

# %%
notas1 = [7, 8, 9]
nota = 0
soma = 0

for nota in notas1:
  soma = soma + nota
  media = soma / len(notas1)
print (f"a soma das notas é {soma}")
print (f"a média das notas é {media}")
# Out:
# a soma das notas é 24
# a média das notas é 8.0
