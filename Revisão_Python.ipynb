# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/EstudoEmCasaPCD/blob/main/Revis%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "Miguel"
# !git config --global user.email "miguel.ramos@sou.unijui.edu.br"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=Miguel
# user.email=miguel.ramos@sou.unijui.edu.br
# init.defaultbranch=main

# %%
# !git clone https://github.com/miguelramos-netizen/EstudoEmCasaPCD.git
# %cd exerciciosemcasa
# !ls
# !git status
# !git remote -v
# Out:
# fatal: destination path 'EstudoEmCasaPCD' already exists and is not an empty directory.
# [Errno 2] No such file or directory: 'exerciciosemcasa'
# /content
# EstudoEmCasaPCD  sample_data
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
